# %%
library (ggplot2)
qplot(x=bodywt, y=sleep_total, data=msleep, facets=vore~., colour=vore, xlim=c(0,1), xlab="Bodyweight (kg)", ylab="Total Sleep (hours)", main="Mammalian Sleep Patterns by Weight (<1kg)") + theme_bw()

# %% [markdown]
# #A qplot study investigating the relationship between bodyweight and total sleep requirements of the smallest mammals in the msleep dataset. As noted, there is generally a positive correlation between weight and sleep (as weight increases, so does total time spent asleep). An exception exists in the herbivore category, which demonstrates a negative correlation. This trend continues when further investigating other weight brackets. The study is restricted in the insectivore category where limited data exists.
