# %%
library (ggplot2)
qplot(x=bodywt, y=sleep_total, data=msleep, facets=vore~., colour=vore, xlim=c(0,1), xlab="Bodyweight (kg)", ylab="Total Sleep (hours)", main="Mammalian Sleep Patterns by Weight (<1kg)") + theme_bw()
