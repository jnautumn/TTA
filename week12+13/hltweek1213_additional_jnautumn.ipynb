# %%
# This R environment comes with many helpful analytics packages installed
# It is defined by the kaggle/rstats Docker image: https://github.com/kaggle/docker-rstats
# For example, here's a helpful package to load

library(tidyverse) # metapackage of all tidyverse packages

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

list.files(path = "../input")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#HLT Additional, 1:
a <- c(1,2,3,4,5)
b <- c(6,7,8,9,10)
c <- c(11,12,13,14,15)
matrix <- cbind(a,b,c)
print(matrix)
library(ggplot2)
qplot (x=a, y=c, geom="line")

# %%
#HLT Additional, 2:
employee = data.frame(Name=c("Andrew","Bobby","Charlie","Donald","Edward"),
                     Age=c(21,22,23,24,25),
                     Role=c("Admin Assistant", "Receptionist", "Cleaner", "Postal Clerk", "CEO"),
                     Length=c("1 Year, 6 Months", "2 Years, 4 Months", "5 Years, 5 Months", "4 Years, 0 Months", "10 Years, 10 Months"))
print(employee)

# %%
#HLT Additional, 3:
sequence <- seq(1,20)
print(sequence)
library(ggplot2)
qplot (x=sequence, y= sequence^2, geom="point")

# %%
#HLT Additional, 4:
library(ggplot2)
bars <- data.frame(
  xaxis=c("1","2","3","4","5") ,  
  yaxis=c(10,20,30,40,50))
ggplot(data, aes(x=xaxis, y=yaxis)) + 
  geom_bar(stat = "identity")

# %%
#HLT Additional, 5:
name <- readline("Enter Your Name: ")
age <- readline("Enter Your Age: ")
print(paste("Hello ", name, ". You are ", age, "years old."))

# %%
#HLT Additional, 6:
seq(20,50)
mean(20:60)
sum(51:91)

# %%
#HLT Additional, 7:
floor(runif(10, min=-50, max=50))

# %%
#HLT Additional: recall values stored in memory, PPT Session 2
print(paste(ls()))
